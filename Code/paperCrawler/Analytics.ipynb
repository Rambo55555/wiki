# %%
import pandas as pd
import requests
import re
from tqdm import tqdm
import time
from bs4 import BeautifulSoup
import json

current_dir = ""

# %%
df = pd.read_csv(current_dir + "paperInfo.csv")
df
# Out:
#            Key  Year                                          Url  \
# 0     C8VSYBES  2023  https://doi.org/10.1109/ASE56229.2023.00213
# 1     8PBLFHI9  2023  https://doi.org/10.1109/ASE56229.2023.00146
# 2     YXIZFW3F  2023  https://doi.org/10.1109/ASE56229.2023.00065
# 3     G9XMACX6  2023  https://doi.org/10.1109/ASE56229.2023.00216
# 4     EUT579M7  2023  https://doi.org/10.1109/ASE56229.2023.00092
# ...        ...   ...                                          ...
# 1155  HAB6J8JW  2023              https://doi.org/10.1145/3563212
# 1156  79Z7UIKV  2023              https://doi.org/10.1145/3571847
# 1157  BKJKTU8E  2023              https://doi.org/10.1145/3582569
# 1158  CAJPIICK  2023              https://doi.org/10.1145/3544792
# 1159  V8CK5GWQ  2023              https://doi.org/10.1145/3544790
#
#      Publication Title                                              Title  \
# 0             ASE 2023  CPA-DF: A Tool for Configurable Interval Analy...
# 1             ASE 2023  Provengo: A Tool Suite for Scenario Driven Mod...
# 2             ASE 2023  Better Patching Using LLM Prompting, via Self-...
# 3             ASE 2023  Optimizing Continuous Development by Detecting...
# 4             ASE 2023  Modeling Programmer Attention as Scanpath Pred...
# ...                ...                                                ...
# 1155        TOSEM 2023  Precise Quantitative Analysis of Binarized Neu...
# 1156        TOSEM 2023  Securing the Ethereum from Smart Ponzi Schemes...
# 1157        TOSEM 2023  Client-Specific Upgrade Compatibility Checking...
# 1158        TOSEM 2023  Efficient and Effective Feature Space Explorat...
# 1159        TOSEM 2023  Toward More Efficient Statistical Debugging wi...
#
#                                            Abstract（英文）  \
# 0     Software verification is challenging, and auxi...
# 1     We present Provengo, a comprehensive suite of ...
# 2     Large Language models (LLMs) can be induced to...
# 3     Continuous development (CD) helps developers q...
# 4     This paper launches a new effort at modeling p...
# ...                                                 ...
# 1155  As a new programming paradigm, neural-network-...
# 1156  Malware detection approaches have been extensi...
# 1157  Modern software systems are complex, and they ...
# 1158  Assessing the quality of Deep Learning (DL) sy...
# 1159  Debugging is known to be a notoriously painsta...
#
#                                                Keywords  \
# 0     Program Analysis,Data Flow Analysis,Software M...
# 1                 Testing,Software engineering,Business
# 2                  LLMs,Self-consistency,Program Repair
# 3     Runtime,Static analysis,Writing,Chatbots,Softw...
# 4     scanpath prediction,human attention,eye tracki...
# ...                                                 ...
# 1155  Computing methodologies,Machine learning,Machi...
# 1156  Security and privacy,Intrusion/anomaly detecti...
# 1157  Software and its engineering,Software creation...
# 1158  Software and its engineering,Software creation...
# 1159  Software and its engineering,Software creation...
#
#                                   标题  \
# 0        CPA-DF：一种可配置区间分析工具，用于增强程序验证
# 1     Provengo：一个用于场景驱动的基于模型的测试的工具套件
# 2               通过自一致性使用LLM提示进行更好的修补
# 3              通过检测和防止不必要的内容生成优化持续开发
# 4                   将程序员注意力建模为扫描路径预测
# ...                              ...
# 1155       二值化神经网络的精确定量分析：一种基于BDD的方法
# 1156         从智能庞氏骗局中保护以太坊：使用静态特征的识别
# 1157       通过知识引导的发现进行特定于客户端的升级兼容性检查
# 1158             用于测试深度学习系统的高效特征空间探索
# 1159                使用抽象精化实现更高效的统计调试
#
#                                            Abstract（中文）  \
# 0     软件验证具有挑战性，使用辅助程序不变量来提高验证方法的有效性。例如，CPACHECKER中的...
# 1     我们介绍了Provengo，这是一套全面的工具，旨在促进场景驱动的基于模型的测试（SDMBT...
# 2     大型语言模型（LLM）可以通过“少量”提示（包括说明性问题解决方案示例）来解决非琐碎的问题。...
# 3     持续开发（CD）帮助开发人员快速发布和更新软件。为了制定CD，开发人员自定义他们的CD构建以...
# 4     本文通过预测眼动扫描路径，对程序员的注意力进行了建模。程序员注意力是指人们在执行编程任务时所...
# ...                                                 ...
# 1155  作为一种新的编程范式，基于神经网络的机器学习已经将其应用扩展到许多现实问题中。由于神经网络的...
# 1156  针对传统软件系统，恶意软件检测方法已被广泛研究。然而，区块链技术的发展推动了一种新型软件系统...
# 1157  现代软件系统是复杂的，它们严重依赖于不同团队和组织开发的外部库。由于库升级引起的不兼容性问题...
# 1158  评估深度学习（DL）系统的质量至关重要，因为它们越来越多地被用于安全关键领域。研究人员提出了...
# 1159  众所周知，调试是一项出了名的费时费力的任务。作为自动化调试的一个主要家族，统计调试方法在过去...
#
#                                                     关键词  可用数据集  源代码  \
# 0                   程序分析，数据流分析，软件模型检查，区间分析，动态精度调整，不变量生成    NaN  NaN
# 1                                            测试，软件工程，商业    NaN  NaN
# 2                                         LLM，自一致性，程序修复    NaN  NaN
# 3                              聊天机器人，静态分析，写作，软件，任务分析，测试    NaN  NaN
# 4                           扫描路径预测，人类注意力，眼睛跟踪，神经网络，人工智能    NaN  NaN
# ...                                                 ...    ...  ...
# 1155  计算方法，机器学习，机器学习方法，神经网络，安全和隐私，软件和应用程序安全，软件安全工程，软...    NaN  NaN
# 1156            安全和隐私，入侵/异常检测和恶意软件缓解，恶意软件及其缓解，软件和应用程序安全    NaN  NaN
# 1157   软件及其工程，软件创建和管理，软件开发后问题，维护软件，软件演化，软件符号和工具，软件库和存储库    NaN  NaN
# 1158              软件及其工程，软件创建和管理，软件验证和确认，软件缺陷分析，软件测试和调试    NaN  NaN
# 1159  软件及其工程，软件创建和管理，软件验证和确认，软件缺陷分析，软件测试和调试，软件符号和工具，...    NaN  NaN
#
#       备注（如改进方向等）
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 1155         NaN
# 1156         NaN
# 1157         NaN
# 1158         NaN
# 1159         NaN
#
# [1160 rows x 13 columns]

# %%
keyword_dic = {}
def statisticsCount(row):
  if isinstance(row['Keywords'], str):
    keywords = row['Keywords'].split(',')
    for keyword in keywords:
      if keyword in keyword_dic.keys():
        keyword_dic[keyword] = keyword_dic[keyword] + 1
      else:
        keyword_dic[keyword] = 1
  return row
df.apply(statisticsCount, axis=1)
# Out:
#            Key  Year                                          Url  \
# 0     C8VSYBES  2023  https://doi.org/10.1109/ASE56229.2023.00213
# 1     8PBLFHI9  2023  https://doi.org/10.1109/ASE56229.2023.00146
# 2     YXIZFW3F  2023  https://doi.org/10.1109/ASE56229.2023.00065
# 3     G9XMACX6  2023  https://doi.org/10.1109/ASE56229.2023.00216
# 4     EUT579M7  2023  https://doi.org/10.1109/ASE56229.2023.00092
# ...        ...   ...                                          ...
# 1155  HAB6J8JW  2023              https://doi.org/10.1145/3563212
# 1156  79Z7UIKV  2023              https://doi.org/10.1145/3571847
# 1157  BKJKTU8E  2023              https://doi.org/10.1145/3582569
# 1158  CAJPIICK  2023              https://doi.org/10.1145/3544792
# 1159  V8CK5GWQ  2023              https://doi.org/10.1145/3544790
#
#      Publication Title                                              Title  \
# 0             ASE 2023  CPA-DF: A Tool for Configurable Interval Analy...
# 1             ASE 2023  Provengo: A Tool Suite for Scenario Driven Mod...
# 2             ASE 2023  Better Patching Using LLM Prompting, via Self-...
# 3             ASE 2023  Optimizing Continuous Development by Detecting...
# 4             ASE 2023  Modeling Programmer Attention as Scanpath Pred...
# ...                ...                                                ...
# 1155        TOSEM 2023  Precise Quantitative Analysis of Binarized Neu...
# 1156        TOSEM 2023  Securing the Ethereum from Smart Ponzi Schemes...
# 1157        TOSEM 2023  Client-Specific Upgrade Compatibility Checking...
# 1158        TOSEM 2023  Efficient and Effective Feature Space Explorat...
# 1159        TOSEM 2023  Toward More Efficient Statistical Debugging wi...
#
#                                            Abstract（英文）  \
# 0     Software verification is challenging, and auxi...
# 1     We present Provengo, a comprehensive suite of ...
# 2     Large Language models (LLMs) can be induced to...
# 3     Continuous development (CD) helps developers q...
# 4     This paper launches a new effort at modeling p...
# ...                                                 ...
# 1155  As a new programming paradigm, neural-network-...
# 1156  Malware detection approaches have been extensi...
# 1157  Modern software systems are complex, and they ...
# 1158  Assessing the quality of Deep Learning (DL) sy...
# 1159  Debugging is known to be a notoriously painsta...
#
#                                                Keywords  \
# 0     Program Analysis,Data Flow Analysis,Software M...
# 1                 Testing,Software engineering,Business
# 2                  LLMs,Self-consistency,Program Repair
# 3     Runtime,Static analysis,Writing,Chatbots,Softw...
# 4     scanpath prediction,human attention,eye tracki...
# ...                                                 ...
# 1155  Computing methodologies,Machine learning,Machi...
# 1156  Security and privacy,Intrusion/anomaly detecti...
# 1157  Software and its engineering,Software creation...
# 1158  Software and its engineering,Software creation...
# 1159  Software and its engineering,Software creation...
#
#                                   标题  \
# 0        CPA-DF：一种可配置区间分析工具，用于增强程序验证
# 1     Provengo：一个用于场景驱动的基于模型的测试的工具套件
# 2               通过自一致性使用LLM提示进行更好的修补
# 3              通过检测和防止不必要的内容生成优化持续开发
# 4                   将程序员注意力建模为扫描路径预测
# ...                              ...
# 1155       二值化神经网络的精确定量分析：一种基于BDD的方法
# 1156         从智能庞氏骗局中保护以太坊：使用静态特征的识别
# 1157       通过知识引导的发现进行特定于客户端的升级兼容性检查
# 1158             用于测试深度学习系统的高效特征空间探索
# 1159                使用抽象精化实现更高效的统计调试
#
#                                            Abstract（中文）  \
# 0     软件验证具有挑战性，使用辅助程序不变量来提高验证方法的有效性。例如，CPACHECKER中的...
# 1     我们介绍了Provengo，这是一套全面的工具，旨在促进场景驱动的基于模型的测试（SDMBT...
# 2     大型语言模型（LLM）可以通过“少量”提示（包括说明性问题解决方案示例）来解决非琐碎的问题。...
# 3     持续开发（CD）帮助开发人员快速发布和更新软件。为了制定CD，开发人员自定义他们的CD构建以...
# 4     本文通过预测眼动扫描路径，对程序员的注意力进行了建模。程序员注意力是指人们在执行编程任务时所...
# ...                                                 ...
# 1155  作为一种新的编程范式，基于神经网络的机器学习已经将其应用扩展到许多现实问题中。由于神经网络的...
# 1156  针对传统软件系统，恶意软件检测方法已被广泛研究。然而，区块链技术的发展推动了一种新型软件系统...
# 1157  现代软件系统是复杂的，它们严重依赖于不同团队和组织开发的外部库。由于库升级引起的不兼容性问题...
# 1158  评估深度学习（DL）系统的质量至关重要，因为它们越来越多地被用于安全关键领域。研究人员提出了...
# 1159  众所周知，调试是一项出了名的费时费力的任务。作为自动化调试的一个主要家族，统计调试方法在过去...
#
#                                                     关键词  可用数据集  源代码  \
# 0                   程序分析，数据流分析，软件模型检查，区间分析，动态精度调整，不变量生成    NaN  NaN
# 1                                            测试，软件工程，商业    NaN  NaN
# 2                                         LLM，自一致性，程序修复    NaN  NaN
# 3                              聊天机器人，静态分析，写作，软件，任务分析，测试    NaN  NaN
# 4                           扫描路径预测，人类注意力，眼睛跟踪，神经网络，人工智能    NaN  NaN
# ...                                                 ...    ...  ...
# 1155  计算方法，机器学习，机器学习方法，神经网络，安全和隐私，软件和应用程序安全，软件安全工程，软...    NaN  NaN
# 1156            安全和隐私，入侵/异常检测和恶意软件缓解，恶意软件及其缓解，软件和应用程序安全    NaN  NaN
# 1157   软件及其工程，软件创建和管理，软件开发后问题，维护软件，软件演化，软件符号和工具，软件库和存储库    NaN  NaN
# 1158              软件及其工程，软件创建和管理，软件验证和确认，软件缺陷分析，软件测试和调试    NaN  NaN
# 1159  软件及其工程，软件创建和管理，软件验证和确认，软件缺陷分析，软件测试和调试，软件符号和工具，...    NaN  NaN
#
#       备注（如改进方向等）
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 1155         NaN
# 1156         NaN
# 1157         NaN
# 1158         NaN
# 1159         NaN
#
# [1160 rows x 13 columns]

# %%
sorted_dict = sorted(keyword_dic.items(), key=lambda x: x[1], reverse=True)
sorted_dict
# Out:
# [('Software and its engineering', 443),
#  ('Software creation and management', 385),
#  ('Software verification and validation', 257),
#  ('Software defect analysis', 188),
#  ('Software notations and tools', 180),
#  ('Software testing and debugging', 174),
#  ('Computing methodologies', 115),
#  ('Software organization and properties', 113),
#  ('Machine learning', 89),
#  ('Security and privacy', 86),
#  ('Social and professional topics', 80),
#  ('Software post-development issues', 76),
#  ('Theory of computation', 66),
#  ('Professional topics', 62),
#  ('Software and application security', 60),
#  ('Software configuration management and version control systems', 57),
#  ('General and reference', 56),
#  ('Human-centered computing', 55),
#  ('Software functional properties', 54),
#  ('Management of computing and information systems', 54),
#  ('Information systems', 49),
#  ('Cross-computing tools and techniques', 44),
#  ('Semantics and reasoning', 42),
#  ('Software maintenance tools', 41),
#  ('Software development techniques', 37),
#  ('Extra-functional properties', 37),
#  ('Artificial intelligence', 37),
#  ('Software security engineering', 36),
#  ('Program reasoning', 36),
#  ('Formal methods', 35),
#  ('Collaboration in software development', 34),
#  ('Machine learning approaches', 34),
#  ('Maintaining software', 32),
#  ('deep learning', 31),
#  ('Computer systems organization', 30),
#  ('Neural networks', 29),
#  ('Software management', 28),
#  ('Software development process management', 27),
#  ('Codes', 26),
#  ('Software evolution', 25),
#  ('Search-based software engineering', 25),
#  ('Formal software verification', 24),
#  ('Information systems applications', 24),
#  ('Natural language processing', 22),
#  ('General programming languages', 22),
#  ('Software system structures', 21),
#  ('machine learning', 20),
#  ('Designing software', 20),
#  ('Program verification', 19),
#  ('Systems security', 19),
#  ('Software performance', 18),
#  ('Empirical software validation', 18),
#  ('Embedded and cyber-physical systems', 18),
#  ('software testing', 17),
#  ('empirical study', 17),
#  ('Deep Learning', 17),
#  ('software engineering', 16),
#  ('static analysis', 16),
#  ('Empirical studies', 16),
#  ('Software libraries and repositories', 16),
#  ('Software engineering', 15),
#  ('Software reliability', 15),
#  ('Computing / technology policy', 15),
#  ('Compilers', 15),
#  ('Computer bugs', 14),
#  ('Fuzzing', 14),
#  ('Information retrieval', 14),
#  ('Automated static analysis', 14),
#  ('Learning paradigms', 13),
#  ('Open source model', 13),
#  ('Program analysis', 12),
#  ('Software', 11),
#  ('Data mining', 11),
#  ('Project and people management', 11),
#  ('Intrusion/anomaly detection and malware mitigation', 11),
#  ('Embedded systems', 10),
#  ('testing', 10),
#  ('Collaborative and social computing', 10),
#  ('Distributed systems organizing principles', 10),
#  ('Human computer interaction (HCI)', 10),
#  ('Logic', 10),
#  ('neural networks', 9),
#  ('fuzzing', 9),
#  ('Deep learning', 9),
#  ('Context specific languages', 9),
#  ('Development frameworks and environments', 9),
#  ('Cloud computing', 9),
#  ('Reusability', 9),
#  ('Automatic programming', 9),
#  ('Logic and verification', 9),
#  ('Task analysis', 8),
#  ('Security', 8),
#  ('Android', 8),
#  ('JavaScript', 8),
#  ('Software maintenance', 8),
#  ('program repair', 8),
#  ('software maintenance', 8),
#  ('Semantics', 8),
#  ('Domain specific languages', 8),
#  ('Networks', 8),
#  ('Ubiquitous and mobile computing', 8),
#  ('Programming teams', 8),
#  ('Theory and algorithms for application domains', 8),
#  ('Architectures', 8),
#  ('Software reverse engineering', 8),
#  ('Static analysis', 7),
#  ('Source coding', 7),
#  ('Java', 7),
#  ('transfer learning', 7),
#  ('Machine Learning', 7),
#  ('Robotics', 7),
#  ('Visualization', 7),
#  ('mining software repositories', 7),
#  ('Retrieval tasks and goals', 7),
#  ('Recommender systems', 7),
#  ('Requirements analysis', 7),
#  ('Operating systems security', 7),
#  ('Language features', 7),
#  ('Training', 6),
#  ('fault localization', 6),
#  ('large language models', 6),
#  ('Performance', 6),
#  ('GUI testing', 6),
#  ('Empirical Study', 6),
#  ('large language model', 6),
#  ('Automated Program Repair', 6),
#  ('Predictive models', 6),
#  ('Reliability', 6),
#  ('Software testing', 6),
#  ('Manuals', 6),
#  ('empirical software engineering', 6),
#  ('natural language processing', 6),
#  ('Modeling and simulation', 6),
#  ('Software version control', 6),
#  ('Applied computing', 6),
#  ('Supervised learning', 6),
#  ('Data management systems', 6),
#  ('Software development methods', 6),
#  ('System description languages', 6),
#  ('Vulnerability management', 6),
#  ('Computer crime', 6),
#  ('Visualization techniques', 6),
#  ('Program Analysis', 5),
#  ('Testing', 5),
#  ('Runtime', 5),
#  ('Vulnerability', 5),
#  ('mobile apps', 5),
#  ('Android apps', 5),
#  ('deep neural networks', 5),
#  ('Measurement', 5),
#  ('refactoring', 5),
#  ('information retrieval', 5),
#  ('program comprehension', 5),
#  ('cyber-physical systems', 5),
#  ('program analysis', 5),
#  ('Maintenance engineering', 5),
#  ('Software Testing', 5),
#  ('bug detection', 5),
#  ('test generation', 5),
#  ('Empirical study', 5),
#  ('dynamic analysis', 5),
#  ('Documentation', 5),
#  ('blockchain', 5),
#  ('smart contract', 5),
#  ('Language types', 5),
#  ('Software architectures', 5),
#  ('Knowledge representation and reasoning', 5),
#  ('Dependable and fault-tolerant systems and networks', 5),
#  ('Redundancy', 5),
#  ('Hardware', 5),
#  ('Machine learning theory', 5),
#  ('Human and societal aspects of security and privacy', 5),
#  ('Distributed architectures', 5),
#  ('Formal methods and theory of security', 5),
#  ('Software system models', 5),
#  ('Software verification', 5),
#  ('Software safety', 5),
#  ('Program Repair', 4),
#  ('artificial intelligence', 4),
#  ('Software systems', 4),
#  ('Privacy', 4),
#  ('Libraries', 4),
#  ('Mining Software Repositories', 4),
#  ('type inference', 4),
#  ('API recommendation', 4),
#  ('Smart contract', 4),
#  ('Software Engineering', 4),
#  ('mutation testing', 4),
#  ('verification', 4),
#  ('Data models', 4),
#  ('Benchmark testing', 4),
#  ('Android app', 4),
#  ('SMT solver', 4),
#  ('Transformers', 4),
#  ('case study', 4),
#  ('Python', 4),
#  ('data quality', 4),
#  ('security', 4),
#  ('vulnerability detection', 4),
#  ('graph neural networks', 4),
#  ('reinforcement learning', 4),
#  ('software quality', 4),
#  ('open source', 4),
#  ('Collaborative and social computing systems and tools', 4),
#  ('Open source software', 4),
#  ('Concurrent computing methodologies', 4),
#  ('Software design tradeoffs', 4),
#  ('Network properties', 4),
#  ('Network reliability', 4),
#  ('Empirical studies in collaborative and social computing', 4),
#  ('Database management system engines', 4),
#  ('Specification languages', 4),
#  ('World Wide Web', 4),
#  ('Web application security', 4),
#  ('Document types', 4),
#  ('Surveys and overviews', 4),
#  ('Formal language definitions', 4),
#  ('Dynamic analysis', 4),
#  ('Malware and its mitigation', 4),
#  ('Models of computation', 4),
#  ('coverage criteria', 4),
#  ('software security', 4),
#  ('Ethereum', 4),
#  ('Writing', 3),
#  ('IoT', 3),
#  ('Sustainable development', 3),
#  ('Static Analysis', 3),
#  ('graph representation learning', 3),
#  ('Scalability', 3),
#  ('Code Generation', 3),
#  ('robustness', 3),
#  ('automation', 3),
#  ('Test data generation', 3),
#  ('software logging', 3),
#  ('Software Security', 3),
#  ('Artificial Intelligence', 3),
#  ('Large Language Model', 3),
#  ('Causality Analysis', 3),
#  ('formal methods', 3),
#  ('GitHub', 3),
#  ('scalability', 3),
#  ('microservice', 3),
#  ('programming languages', 3),
#  ('automated program repair', 3),
#  ('symbolic execution', 3),
#  ('Reinforcement learning', 3),
#  ('code generation', 3),
#  ('Stack Overflow', 3),
#  ('dataset', 3),
#  ('Anomaly Detection', 3),
#  ('Costs', 3),
#  ('fairness', 3),
#  ('Reactive synthesis', 3),
#  ('Formal specifications', 3),
#  ('automated testing', 3),
#  ('software development', 3),
#  ('Debugging', 3),
#  ('diversity', 3),
#  ('Blockchain', 3),
#  ('representation learning', 3),
#  ('Systematics', 3),
#  ('productivity', 3),
#  ('AI for SE', 3),
#  ('Software vulnerability', 3),
#  ('metamorphic testing', 3),
#  ('CWE', 3),
#  ('CVE', 3),
#  ('Cyber-physical systems', 3),
#  ('survey', 3),
#  ('Metamorphic testing', 3),
#  ('bug finding', 3),
#  ('Metrics', 3),
#  ('Software usability', 3),
#  ('Empirical studies in HCI', 3),
#  ('Process validation', 3),
#  ('Supervised learning by classification', 3),
#  ('Computing and business', 3),
#  ('Power and energy', 3),
#  ('Power estimation and optimization', 3),
#  ('Formal languages and automata theory', 3),
#  ('Web services', 3),
#  ('RESTful web services', 3),
#  ('Collaborative and social computing theory', 3),
#  (' concepts and paradigms', 3),
#  ('Network security', 3),
#  ('Program semantics', 3),
#  ('HCI design and evaluation methods', 3),
#  ('Mathematics of computing', 3),
#  ('Source code generation', 3),
#  ('Software implementation planning', 3),
#  ('Software product lines', 3),
#  ('Verification by model checking', 3),
#  ('Security in hardware', 3),
#  ('Embedded systems security', 3),
#  ('Model-driven software engineering', 3),
#  ('Domain-specific security and privacy architectures', 3),
#  ('benchmark', 3),
#  ('Technical debt', 3),
#  ('online learning', 3),
#  ('concept drift', 3),
#  ('verification latency', 3),
#  ('mixed-methods', 3),
#  ('stack overflow', 3),
#  ('grounded theory', 3),
#  ('software teams', 3),
#  ('state abstraction', 3),
#  ('Correctness', 3),
#  ('Software design engineering', 3),
#  ('Real-time systems', 3),
#  ('LLMs', 2),
#  ('Chatbots', 2),
#  ('Software quality', 2),
#  ('Solidity', 2),
#  ('Automated Testing', 2),
#  ('Cybersecurity', 2),
#  ('app reviews', 2),
#  ('user feedback', 2),
#  ('Generative AI', 2),
#  ('Industries', 2),
#  ('compiler testing', 2),
#  ('active learning', 2),
#  ('Software Evolution', 2),
#  ('cloud systems', 2),
#  ('PyPI', 2),
#  ('Explainable AI', 2),
#  ('Code Representation Learning', 2),
#  ('zero-shot learning', 2),
#  ('generative model', 2),
#  ('Malware Detection', 2),
#  ('Large language model', 2),
#  ('ChatGPT', 2),
#  ('knowledge management', 2),
#  ('Benchmark', 2),
#  ('Evaluation', 2),
#  ('WebAssembly', 2),
#  ('differential testing', 2),
#  ('knowledge graph', 2),
#  ('Fine-Tuning', 2),
#  ('Graph Neural Networks', 2),
#  ('requirements elicitation', 2),
#  ('Taint analysis', 2),
#  ('Fault Localization', 2),
#  ('Computer languages', 2),
#  ('Filtering', 2),
#  ('History', 2),
#  ('Machine learning algorithms', 2),
#  ('Reliability engineering', 2),
#  ('mutation analysis', 2),
#  ('Software Verification', 2),
#  ('Regression Testing', 2),
#  ('Automation', 2),
#  ('deep learning testing', 2),
#  ('Program repair', 2),
#  ('test case generation', 2),
#  ('constraint solving', 2),
#  ('dependency management', 2),
#  ('Open Source Software', 2),
#  ('Buildings', 2),
#  ('Commit Message Generation', 2),
#  ('metamorphic relations', 2),
#  ('Test Program Generation', 2),
#  ('Internet of Things', 2),
#  ('fuzz testing', 2),
#  ('static taint analysis', 2),
#  ('control flow', 2),
#  ('Code Model', 2),
#  ('data augmentation', 2),
#  ('Smart Contract', 2),
#  ('DeFi', 2),
#  ('software defect prediction', 2),
#  ('sustainability', 2),
#  ('Complexity theory', 2),
#  ('devops', 2),
#  ('infrastructure as code', 2),
#  ('test completion', 2),
#  ('Vulnerability Detection', 2),
#  ('Dependency', 2),
#  ('ethics', 2),
#  ('developer productivity', 2),
#  ('Large Language Models', 2),
#  ('threats to validity', 2),
#  ('Training data', 2),
#  ('qualitative research', 2),
#  ('Databases', 2),
#  ('Reinforcement Learning', 2),
#  ('Configuration', 2),
#  ('Black-box testing', 2),
#  ('Automated software testing', 2),
#  ('software vulnerability', 2),
#  ('Database system', 2),
#  ('interviews', 2),
#  ('Robustness', 2),
#  ('Cloning', 2),
#  ('search-based software testing', 2),
#  ('log parsing', 2),
#  ('recurrent neural networks', 2),
#  ('machine learning testing', 2),
#  ('JVM', 2),
#  ('Schedules', 2),
#  ('Image edge detection', 2),
#  ('few-shot learning', 2),
#  ('algorithm selection', 2),
#  ('test suite generation', 2),
#  ('python', 2),
#  ('Closed box', 2),
#  ('Contrastive Learning', 2),
#  ('Representation learning', 2),
#  ('transformers', 2),
#  ('Production', 2),
#  ('neural machine translation', 2),
#  ('API', 2),
#  ('Refactoring', 2),
#  ('PageRank', 2),
#  ('Genetic algorithm', 2),
#  ('performance', 2),
#  ('deep neural network', 2),
#  ('mobile app', 2),
#  ('code search', 2),
#  ('user study', 2),
#  ('newcomer', 2),
#  ('taint analysis', 2),
#  ('human factors', 2),
#  ('graph neural network', 2),
#  ('correlation', 2),
#  ('Virtual reality', 2),
#  ('Vulnerability detection', 2),
#  ('data sampling', 2),
#  ('Object oriented languages', 2),
#  ('Information extraction', 2),
#  ('Contextual software domains', 2),
#  ('Acceptance testing', 2),
#  ('Machine translation', 2),
#  ('Grammars and context-free languages', 2),
#  ('Enterprise computing', 2),
#  ('Service-oriented architectures', 2),
#  ('Software fault tolerance', 2),
#  ('Application specific development environments', 2),
#  ('Social aspects of security and privacy', 2),
#  ('Information integration', 2),
#  ('Information retrieval query processing', 2),
#  ('Education', 2),
#  ('Computer-assisted instruction', 2),
#  ('Probability and statistics', 2),
#  ('Control methods', 2),
#  ('Constraint and logic programming', 2),
#  ('Automated reasoning', 2),
#  ('Other architectures', 2),
#  ('Security services', 2),
#  ('Retrieval models and ranking', 2),
#  ('Vulnerability scanners', 2),
#  ('Database query processing', 2),
#  ('Mathematical optimization', 2),
#  ('Computer graphics', 2),
#  ('Concurrent programming languages', 2),
#  ('systematic mapping study', 2),
#  ('formal verification', 2),
#  ('effectiveness', 2),
#  ('Bug reporting', 2),
#  ('object detection', 2),
#  ('taxonomy', 2),
#  ('Just-in-time software defect prediction', 2),
#  ('privacy', 2),
#  ('domain-specific languages', 2),
#  ('reverse engineering', 2),
#  ('learning-to-rank', 2),
#  ('patch', 2),
#  ('maintenance', 2),
#  ('smart contracts', 2),
#  ('ethereum', 2),
#  ('behavioral programming', 2),
#  ('efficiency', 2),
#  ('satisfaction', 2),
#  ('family of experiments', 2),
#  ('explainable AI', 2),
#  ('topic modeling', 2),
#  ('Crowdsourced testing', 2),
#  ('software metrics', 2),
#  ('microservices', 2),
#  ('Human factors', 2),
#  ('search-based software engineering', 2),
#  ('Bug', 2),
#  ('human aspects', 2),
#  ('Evidence-based software engineering', 2),
#  ('systematic reviews', 2),
#  ('mixed-methods reviews', 2),
#  ('open source software', 2),
#  ('defect prediction', 2),
#  ('Hoare logic', 2),
#  ('Code search', 2),
#  ('Affects', 2),
#  ('changes', 2),
#  ('emotions', 2),
#  ('requirements', 2),
#  ('socio-technical grounded theory', 2),
#  ('workplace awareness', 2),
#  ('compatibility issues', 2),
#  ('hyperparameter optimization', 2),
#  ('Requirements engineering', 2),
#  ('control flow graph', 2),
#  ('autonomous vehicles', 2),
#  ('Fault localization', 2),
#  ('Design patterns', 2),
#  ('User studies', 2),
#  ('Network protocols', 2),
#  ('Protocol correctness', 2),
#  ('Protocol testing and verification', 2),
#  ('Model development and analysis', 2),
#  ('Estimation', 2),
#  ('Risk management', 2),
#  ('Integrated and visual development environments', 2),
#  ('Agile software development', 2),
#  ('Timed and hybrid models', 2),
#  ('Data Flow Analysis', 1),
#  ('Software Model Checking', 1),
#  ('Interval Analysis', 1),
#  ('Dynamic Precision Adjustment', 1),
#  ('Invariant Generation', 1),
#  ('Business', 1),
#  ('Self-consistency', 1),
#  ('scanpath prediction', 1),
#  ('human attention', 1),
#  ('eye tracking', 1),
#  ('Stakeholders', 1),
#  ('Bytecode', 1),
#  ('EVM', 1),
#  ('bug', 1),
#  ('fault', 1),
#  ('defect benchmark', 1),
#  ('Validation', 1),
#  ('Networking', 1),
#  ('Empirical Software Engineering', 1),
#  ('digital transformation', 1),
#  ('Deep Learning Testing', 1),
#  ('Coverage Guided Fuzzing', 1),
#  ('Data Augmentation', 1),
#  ('Safe AI', 1),
#  ('Energy consumption', 1),
#  ('Metaverse', 1),
#  ('Carbon dioxide', 1),
#  ('Self-Admitted Technical Debt', 1),
#  ('Pre-trained models', 1),
#  ('Machine Learning for Code', 1),
#  ('Privacy protection', 1),
#  ('Permission control', 1),
#  ('Control flow graphs', 1),
#  ('Graph embedding', 1),
#  ('Classification', 1),
#  ('Banking apps', 1),
#  ('Industry practice', 1),
#  ('Code Review', 1),
#  ('Continuous Integration', 1),
#  ('Waste', 1),
#  ('Automated Driving Software', 1),
#  ('Code Clone', 1),
#  ('Comodification', 1),
#  ('Bug-proneness', 1),
#  ('Software Modularity', 1),
#  ('WeChat Mini-programs', 1),
#  ('Taint detection', 1),
#  ('Secu-rity', 1),
#  ('Cloud Computing', 1),
#  ('Microservice', 1),
#  ('QoS', 1),
#  ('Resource Management', 1),
#  ('Holistic Autoscaling', 1),
#  ('Graph Convolution', 1),
#  ('Container', 1),
#  ('code extraction', 1),
#  ('coding screencasts', 1),
#  ('code-aware model', 1),
#  ('optical character recognition', 1),
#  ('Python Native Code', 1),
#  ('Reference Counting', 1),
#  ('Memory Error', 1),
#  ('linear temporal logic', 1),
#  ('satisfiability checking', 1),
#  ('quantum programming language', 1),
#  ('Quantum Intermediate Representation', 1),
#  ('formal syntax and semantics', 1),
#  ('Third-party Library', 1),
#  ('Language Model', 1),
#  ('miscompilation', 1),
#  ('compiler defect', 1),
#  ('crossover', 1),
#  ('HarmonyOS', 1),
#  ('Framework Base', 1),
#  ('Compatibility Issue', 1),
#  ('image recognition', 1),
#  ('deep learning framework conversions', 1),
#  ('malware app', 1),
#  ('many-objective genetic algorithm', 1),
#  ('malicious component', 1),
#  ('Web', 1),
#  ('Library Detection', 1),
#  ('Front end', 1),
#  ('pre-trained code models', 1),
#  ('fine-tuning', 1),
#  ('parameter-efficient', 1),
#  ('alarm ranking', 1),
#  ('Entity Matching', 1),
#  ('Software Refactoring', 1),
#  ('Entity Tracking', 1),
#  ('Automatic Speech Recognition', 1),
#  ('Accessibility Testing', 1),
#  ('virtual device', 1),
#  ('DMA', 1),
#  ('satisfiability modulo theories', 1),
#  ('nonlinear real arithmetic', 1),
#  ('gradient-based optimization', 1),
#  ('functional clusters', 1),
#  ('cloud observability', 1),
#  ('instances', 1),
#  ('software reliability', 1),
#  ('Software Debloating', 1),
#  ('react native', 1),
#  ('Iterative Element Matching', 1),
#  ('Web Testing', 1),
#  ('Test Repair', 1),
#  ('malicious package detection', 1),
#  ('code clustering', 1),
#  ('code classification', 1),
#  ('failure-inducing test cases', 1),
#  ('program intention inference', 1),
#  ('program generation', 1),
#  ('Contextualized Embedding', 1),
#  ('Contextuality of Code Embedding', 1),
#  ('Semantic Versioning', 1),
#  ('Breaking Change', 1),
#  ('Third-Party Library', 1),
#  ('Go Ecosystem', 1),
#  ('code clone detection', 1),
#  ('cross-language', 1),
#  ('Open Source Software Licenses', 1),
#  ('Multi-Task Learning', 1),
#  ('License comprehension', 1),
#  ('decision-making policies', 1),
#  ('Software Supply Chain Security', 1),
#  ('Security Tools', 1),
#  ('Batch verification', 1),
#  ('Homogeneous structure', 1),
#  ('Abstraction', 1),
#  ('software development productivity', 1),
#  ('Mutation testing', 1),
#  ('Self Adaptation', 1),
#  ('Self-adaptive systems', 1),
#  ('Software Architecture', 1),
#  ('ML-Enabled Systems', 1),
#  ('ML4SA', 1),
#  ('Unsupervised Learning', 1),
#  ('Object Detection', 1),
#  ('log messages', 1),
#  ('Could Computing', 1),
#  ('Anomaly Anticipation', 1),
#  ('Denosing Diffusion Model', 1),
#  ('Performance Metric', 1),
#  ('Log analytics', 1),
#  ('Log parsing', 1),
#  ('OS kernel', 1),
#  ('Industrial Control Systems', 1),
#  ('Learning based Approaches', 1),
#  ('Security Attack', 1),
#  ('bus factor', 1),
#  ('truck factor', 1),
#  ('intelligent collaboration tools', 1),
#  ('Reinforcement Learning for Testing', 1),
#  ('Automated REST API Testing', 1),
#  ('graph execution', 1),
#  ('Pluggable type systems', 1),
#  ('type qualifiers', 1),
#  ('type-checking', 1),
#  ('Secure Coding Practice', 1),
#  ('Satisfiability Modulo Theories', 1),
#  ('Model Constructing Satisfiability', 1),
#  ('Probability Distribution', 1),
#  ('Test migration', 1),
#  ('vision-based GUI analysis', 1),
#  ('Fairness', 1),
#  ('Performance Debugging', 1),
#  ('Chaos Engineering', 1),
#  ('Code Translation', 1),
#  ('performance issues', 1),
#  ('Go', 1),
#  ('Concurrency Testing', 1),
#  ('anomaly detection', 1),
#  ('multi-modal learning', 1),
#  ('system twin graph', 1),
#  ('query clarification', 1),
#  ('out-of-vocabulary', 1),
#  ('Large Language Models of Code', 1),
#  ('Neural Machine Translation', 1),
#  ('high-availability', 1),
#  ('log-based software', 1),
#  ('automatic recovery', 1),
#  ('Legged locomotion', 1),
#  ('Software algorithms', 1),
#  ('Data Analytics', 1),
#  ('Cloud Access Control', 1),
#  ('MaxSAT', 1),
#  ('distributed compilation', 1),
#  ('linear regression', 1),
#  ('compilation resources', 1),
#  ('Test code maintenance', 1),
#  ('Multi-label Image Classification Testing', 1),
#  ('Black-box Testing', 1),
#  ('Metamorphic Testing', 1),
#  ('MAP', 1),
#  ('mean average precision', 1),
#  ('PyPI Ecosystem', 1),
#  ('Package Management', 1),
#  ('Malicious Code', 1),
#  ('Mirror Source', 1),
#  ('Lifecycle Portrait', 1),
#  ('traceability analysis', 1),
#  ('Smoothing methods', 1),
#  ('Transform coding', 1),
#  ('Boosting', 1),
#  ('issue tracking', 1),
#  ('issue prioritization', 1),
#  ('text analytics', 1),
#  ('comment-code inconsistency', 1),
#  ('Predictive maintenance', 1),
#  ('Prediction methods', 1),
#  ('Repair', 1),
#  ('IFDS', 1),
#  ('precision', 1),
#  ('Deep Neural Network', 1),
#  ('Mutation', 1),
#  (' test automation', 1),
#  ('gRPC', 1),
#  ('dependency recovery', 1),
#  ('Merge Conflict Resolution', 1),
#  ('Generative Models', 1),
#  ('Conflict Representation', 1),
#  ('AutoML', 1),
#  ('Representation Learning', 1),
#  ('Focusing', 1),
#  ('Static Program Analysis', 1),
#  ('Modular Analysis', 1),
#  ('Result Reuse', 1),
#  ('Repository Mining', 1),
#  ('Bug Triaging', 1),
#  ('Transformer', 1),
#  ('Text-Embedding', 1),
#  ('DL4SE', 1),
#  ('Thread Misuse', 1),
#  ('Basic Thread', 1),
#  ('Runnable', 1),
#  ('Java Program', 1),
#  ('Linked Alerts', 1),
#  ('Online Service Systems', 1),
#  ('Synthesizers', 1),
#  ('Reliability theory', 1),
#  ('Data science', 1),
#  ('Simulink models', 1),
#  ('program analysis verification and testing', 1),
#  ('graduate level course', 1),
#  ('education', 1),
#  ('energy measurement', 1),
#  ('R', 1),
#  ('Intel-RAPL', 1),
#  ('flaky tests', 1),
#  ('non-determinism', 1),
#  ('System Monitoring', 1),
#  ('Cloud Services', 1),
#  ('Causal Graph', 1),
#  ('Knowledge Graph', 1),
#  ('Formal Methods', 1),
#  ('Program Correctness', 1),
#  ('Automatic Verification', 1),
#  ('Verification Tools', 1),
#  ('Provers', 1),
#  ('Program Invariants', 1),
#  ('Autonomous systems', 1),
#  ('Simulation Environment', 1),
#  ('CAN Bus', 1),
#  ('Loop Abstraction', 1),
#  ('Precision Adjustment', 1),
#  ('CEGAR', 1),
#  ('CPAchecker', 1),
#  ('Program Transformations', 1),
#  ('design', 1),
#  ('design review', 1),
#  ('review and evaluation', 1),
#  ('peer reviewing', 1),
#  ('architecture review', 1),
#  ('engineering design', 1),
#  ('Compiler', 1),
#  ('Compiler Auto-tuning', 1),
#  ('Critical Flag Selection', 1),
#  ('Search', 1),
#  ('Patch robustness', 1),
#  ('certification', 1),
#  ('invariant', 1),
#  ('Differential Testing', 1),
#  ('automated dataset constructing', 1),
#  ('bug-fix dataset', 1),
#  ('neural program repair', 1),
#  ('fuzzy logic model', 1),
#  ('SMT', 1),
#  ('Tail', 1),
#  ('Behavioral sciences', 1),
#  ('Neural Network Verification', 1),
#  ('Network Reduction', 1),
#  ('Pre-processing', 1),
#  ('Deep neural network', 1),
#  ('test input prioritization', 1),
#  ('movement cost', 1),
#  ('certifiable prioritization', 1),
#  ('Non-termination detection', 1),
#  ('Dynamic testing', 1),
#  ('Testing oracle generation', 1),
#  ('issue-commit link recovery', 1),
#  ('software traceability', 1),
#  ('Compilation Error', 1),
#  ('CFL Reachability', 1),
#  ('Simulation', 1),
#  ('Automated Analysis', 1),
#  ('Uncrewed Aerial Vehicles', 1),
#  ('Data minimization principle', 1),
#  ('Privacy violation detection', 1),
#  ('Android App', 1),
#  ('Inter-Component Communication', 1),
#  ('Combinatorial Testing', 1),
#  ('Extrapolation', 1),
#  ('Error analysis', 1),
#  ('Vulnerability Diagnosis', 1),
#  ('Vulnerability Localization', 1),
#  ('Description Generation', 1),
#  ('Open-source Software', 1),
#  ('Regex Generation', 1),
#  ('Chain of Inference', 1),
#  ('Self-Consistency Decoding', 1),
#  ('Fix Pattern', 1),
#  ('Pretrained Model', 1),
#  ('LLM4SE', 1),
#  ('AST mapping', 1),
#  ('Code change analysis', 1),
#  ('Model Universe', 1),
#  ('System Universe', 1),
#  ('Coevolution', 1),
#  ('Epigenetics', 1),
#  ('Bug datasets', 1),
#  ('Scene-driven exploration', 1),
#  ('GUI exploration', 1),
#  ('GUI modeling', 1),
#  ('arduino programming', 1),
#  ('Quantum program', 1),
#  ('magnitude', 1),
#  ('phase', 1),
#  ('entanglement', 1),
#  ('Invariant generation', 1),
#  ('comparison and analysis', 1),
#  ('program competition', 1),
#  ('Chat-GPT', 1),
#  ('clean code', 1),
#  ('Deep Reinforcement Learning', 1),
#  ('Software Healing', 1),
#  ('Intentional Forgetting', 1),
#  ('Continual Learning', 1),
#  ('Actionable warning recommendation', 1),
#  ('Weak supervision', 1),
#  ('C program repair', 1),
#  ('test-independent repair', 1),
#  ('preprocessor directives', 1),
#  ('industrial solutions', 1),
#  ('Software Q&A', 1),
#  ('open source license', 1),
#  ('license incompatibility and its remediation', 1),
#  ('Physics simulator', 1),
#  ('Incompatibility issue', 1),
#  ('software libraries', 1),
#  ('AIoT System', 1),
#  ('Edge Computing', 1),
#  ('Service Collaboration', 1),
#  ('AI Application', 1),
#  ('Data Security', 1),
#  ('Reverse Engineering', 1),
#  ('Binary Diffing', 1),
#  ('Information Inference', 1),
#  ('Programming Language Model', 1),
#  ('Patch Validation', 1),
#  ('Mutation Analysis', 1),
#  ('Test Execution', 1),
#  ('NLP Software Testing', 1),
#  ('Particle Swarm Optimization', 1),
#  ('Surgery', 1),
#  ('Software vulnerability detection', 1),
#  ('positive and unlabeled learning', 1),
#  ('source code representation', 1),
#  ('Diversity of Forks', 1),
#  ('Fork Entropy', 1),
#  ("Rao's Quadratic Entropy", 1),
#  ('Log Analysis', 1),
#  ('Log Instability', 1),
#  ('Online Learning', 1),
#  ('variable explanation', 1),
#  ('naming quality', 1),
#  ('code pretrained models', 1),
#  ('prompt learning', 1),
#  ('Trajectory', 1),
#  ('Best practices', 1),
#  ('Software development management', 1),
#  ('Guidelines', 1),
#  ('Uncertainty', 1),
#  ('Dataset Construction', 1),
#  ('Virtual Reality', 1),
#  ('Scene Exploration', 1),
#  ('Data collection', 1),
#  ('Bug fix', 1),
#  ('content moderation software', 1),
#  ('Compiler Fuzzing', 1),
#  ('MLIR Compiler Infrastructure', 1),
#  ('smart home platform', 1),
#  ('TAP', 1),
#  ('automation application interference', 1),
#  ('quantum programs', 1),
#  ('combinatorial testing', 1),
#  ('self-adaptive', 1),
#  ('energy-aware', 1),
#  ('AI-based', 1),
#  ('multi-objective', 1),
#  ('edge computing', 1),
#  ('internet-of-things', 1),
#  ('configuration', 1),
#  ('data flow', 1),
#  ('code readability', 1),
#  ('t5', 1),
#  ('client-side', 1),
#  ('lazy loading', 1),
#  ('dynamic loading', 1),
#  ('dataset management', 1),
#  ('training automation', 1),
#  ('deep model', 1),
#  ('augmentation', 1),
#  ('impact analysis', 1),
#  ('data constraint', 1),
#  ('FinTech application', 1),
#  ('SZZ Algorithm', 1),
#  ('Heterogeneous Graph Attention Network', 1),
#  ('Learning to Rank', 1),
#  ('Unit Testing', 1),
#  ('Assertion Generation', 1),
#  ('Test Assertion', 1),
#  ('Relational Model Finders', 1),
#  ('Live Programming', 1),
#  ('Input Denoising', 1),
#  ('Adversarial Example', 1),
#  ('Guided Testing', 1),
#  ('Code Transformation', 1),
#  ('domain adaptive code completion', 1),
#  ('retrieval-augment language model', 1),
#  ('Autonomous agents', 1),
#  ('Large Language Models (LLMs)', 1),
#  ('SDLC', 1),
#  ('retrain-finetune', 1),
#  ('Open-Source Incentive', 1),
#  ('Token Leaking', 1),
#  ('CFL-Reachability', 1),
#  ('transitive relations', 1),
#  ('memory leaks', 1),
#  ('non-intrusive fixes', 1),
#  ('single page applications', 1),
#  ('API aspects', 1),
#  ('Contrastive learning', 1),
#  ('API review', 1),
#  ('Aspect detection', 1),
#  ('LIME', 1),
#  ('Nokia 5G', 1),
#  ('industry introduction', 1),
#  ('experience paper', 1),
#  ('bug dataset', 1),
#  ('bug-fixing', 1),
#  ('bug-inducing', 1),
#  ('automatic bug mining', 1),
#  ('green AI', 1),
#  ('carbon emissions', 1),
#  ('Clustering algorithms', 1),
#  ('Bayes methods', 1),
#  ('Unsupervised learning', 1),
#  ('Optimization', 1),
#  ('Concurrent program', 1),
#  ('reactive synthesis', 1),
#  ('symbolic algorithms', 1),
#  ('program synthesis', 1),
#  ('two-player games', 1),
#  ('code smells', 1),
#  ('security smells', 1),
#  ('design smells', 1),
#  ('implementation smells', 1),
#  ('Ansible', 1),
#  ('Chef', 1),
#  ('Docker', 1),
#  ('Puppet', 1),
#  ('Terraform', 1),
#  ('intermediate model', 1),
#  ('Knowledge-driven Prompt', 1),
#  ('API Misuse', 1),
#  ('Prompt Engineering', 1),
#  ('LLM', 1),
#  ('Ontology', 1),
#  ...]

# %%
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
# pd.set_option('max_colwidth',100)

df = df.dropna(subset=['Abstract（英文）'])
commit_df = df[df['Title'].str.lower().str.contains("commit message")]
print(len(commit_df))
commit_df
# Out:
# 5
#           Key  Year                                           Url  \
# 95   7FM8PQAR  2023   https://doi.org/10.1109/ASE56229.2023.00078
# 156  EA26F5HY  2023   https://doi.org/10.1109/ASE56229.2023.00050
# 238  3L6D7IAV  2023  https://doi.org/10.1109/ICSE48619.2023.00075
# 290  6WZZD6M7  2023  https://doi.org/10.1109/ICSE48619.2023.00076
# 642  YQSK3RMA  2023       https://doi.org/10.1145/3597926.3598096
#
#     Publication Title                                              Title  \
# 95           ASE 2023  From Commit Message Generation to History-Awar...
# 156          ASE 2023  Delving into Commit-Issue Correlation to Enhan...
# 238         ICSE 2023  Revisiting Learning-based Commit Message Gener...
# 290         ICSE 2023  Commit Message Matters: Investigating Impact a...
# 642        ISSTA 2023  COME: Commit Message Generation with Modificat...
#
#                                           Abstract（英文）  \
# 95   Commit messages are crucial to software develo...
# 156  Commit message generation (CMG) is a challengi...
# 238  Commit messages summarize code changes and hel...
# 290  Commit messages play an important role in comm...
# 642  Commit messages concisely describe code change...
#
#                                               Keywords  \
# 95   Computer languages,Filtering,Focusing,Writing,...
# 156  Commit Message Generation,Dataset Construction...
# 238  Commit Message Generation,Deep Learning,Patter...
# 290  Commit message quality,software defect pronene...
# 642  Software and its engineering,Software notation...
#
#                          标题  \
# 95       从提交消息生成到历史感知提交消息完成
# 156  深入研究提交问题相关性以增强提交消息生成模型
# 238         重新审视基于学习的提交消息生成
# 290   提交消息事项：调查提交消息质量的影响和演变
# 642        COME：嵌入修改的提交消息生成
#
#                                           Abstract（中文）  \
# 95   提交消息对软件开发至关重要，使开发人员能够跟踪更改并进行有效协作。尽管它们很有用，但大多数提...
# 156  提交消息生成（CMG）是自动化软件工程中一项具有挑战性的任务，旨在为提交生成代码更改的自然语...
# 238  提交消息总结代码更改并帮助开发人员理解其意图。为了减轻人类在编写提交消息方面的努力，研究人员...
# 290  提交消息在开发人员之间的沟通中起着重要作用。为了衡量提交消息的质量，研究人员定义了什么在语义...
# 642  提交消息简洁地描述了自然语言中的代码更改，对程序的理解和维护很重要。先前的研究提出了一些自动...
#
#                           关键词  可用数据集  源代码  备注（如改进方向等）
# 95   计算机语言，过滤，聚焦，写作，软件，历史，可靠性    NaN  NaN         NaN
# 156       提交消息生成，数据集构建，代码表示学习    NaN  NaN         NaN
# 238          提交消息生成，深度学习，基于模式    NaN  NaN         NaN
# 290        承诺消息质量，软件缺陷倾向，实证分析    NaN  NaN         NaN
# 642     软件及其工程，软件符号和工具，软件维护工具    NaN  NaN         NaN
